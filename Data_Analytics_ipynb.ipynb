# %% [markdown]
# #Etapa 1

# %% [markdown]
# ## 1.- Cargar los sets de datos como DataFrames

# %%
# Importar librerías
import pandas as pd
import numpy as n
import os

# Cargar los datasets
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
os.listdir("/content/drive/MyDrive/datasets")
# Out:
# ['titanic.csv', 'clientes.csv', 'marketing.csv', 'ventas.csv']

# %%
ruta_ventas = "/content/drive/MyDrive/datasets/ventas.csv"
ruta_clientes = "/content/drive/MyDrive/datasets/clientes.csv"
ruta_marketing = "/content/drive/MyDrive/datasets/marketing.csv"

# Cargamos los CSV como DataFrames.
ventas = pd.read_csv(ruta_ventas)
clientes = pd.read_csv(ruta_clientes)
marketing = pd.read_csv(ruta_marketing)

# Mostrar una vista rápida de los primeros registros
print("Clientes:")
display(clientes.head())

print("Ventas:")
display(ventas.head())

print("Marketing:")
display(marketing.head())
# Out:
# Clientes:
#    id_cliente               nombre  edad         ciudad  ingresos
# 0           1      Aloysia Screase    44  Mar del Plata  42294.68
# 1           2  Kristina Scaplehorn    25        Posadas  24735.04
# 2           3       Filip Castagne    50    Resistencia  35744.85
# 3           4          Liuka Luard    39   Bahía Blanca  27647.96
# 4           5        Dore Cockshtt    28        Rosario  28245.65
# Ventas:
#    id_venta           producto   precio  cantidad fecha_venta  \
# 0       792  Cuadro decorativo   $69.94       5.0  02/01/2024
# 1       811    Lámpara de mesa  $105.10       5.0  02/01/2024
# 2      1156           Secadora   $97.96       3.0  02/01/2024
# 3      1372           Heladera  $114.35       8.0  02/01/2024
# 4      1546           Secadora  $106.21       4.0  02/01/2024
#
#            categoria
# 0         Decoración
# 1         Decoración
# 2  Electrodomésticos
# 3  Electrodomésticos
# 4  Electrodomésticos
# Marketing:
# ...

# %% [markdown]
# ## 2.- Introducción a Pandas: análisis exploratorio inicial

# %%
# Tamaño y tipo de datos
print("Clientes:")
print(clientes.info(), "\n")

print("Ventas:")
print(ventas.info(), "\n")

print("Marketing:")
print(marketing.info(), "\n")

# Estadísticas descriptivas
print("Estadísticas - Clientes")
display(clientes.describe(include='all'))

print("Estadísticas - Ventas")
display(ventas.describe(include='all'))

print("Estadísticas - Marketing")
display(marketing.describe(include='all'))
# Out:
# Clientes:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 567 entries, 0 to 566
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id_cliente  567 non-null    int64
#  1   nombre      567 non-null    object
#  2   edad        567 non-null    int64
#  3   ciudad      567 non-null    object
#  4   ingresos    567 non-null    float64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 22.3+ KB
# None
#
# Ventas:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3035 entries, 0 to 3034
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id_venta     3035 non-null   int64
#  1   producto     3035 non-null   object
#  2   precio       3033 non-null   object
#  3   cantidad     3033 non-null   float64
#  4   fecha_venta  3035 non-null   object
#  5   categoria    3035 non-null   object
# dtypes: float64(1), int64(1), object(4)
# ...

# %% [markdown]
# ## 3.- Calidad de Datos: valores nulos y duplicados

# %%
# Valores nulos
print("Valores nulos por dataset:")
print("Clientes:\n", clientes.isnull().sum(), "\n")
print("Ventas:\n", ventas.isnull().sum(), "\n")
print("Marketing:\n", marketing.isnull().sum(), "\n")

# Duplicados
print("Duplicados por dataset:")
print("Clientes:", clientes.duplicated().sum())
print("Ventas:", ventas.duplicated().sum())
print("Marketing:", marketing.duplicated().sum())

# Documentar el estado inicial de los datos
estado_datos = pd.DataFrame({
    'Dataset': ['Clientes', 'Ventas', 'Marketing'],
    'Filas': [clientes.shape[0], ventas.shape[0], marketing.shape[0]],
    'Columnas': [clientes.shape[1], ventas.shape[1], marketing.shape[1]],
    'Duplicados': [clientes.duplicated().sum(), ventas.duplicated().sum(), marketing.duplicated().sum()],
    'Valores Nulos Totales': [
        clientes.isnull().sum().sum(),
        ventas.isnull().sum().sum(),
        marketing.isnull().sum().sum()
    ]
})

display(estado_datos)
# Out:
# Valores nulos por dataset:
# Clientes:
#  id_cliente    0
# nombre        0
# edad          0
# ciudad        0
# ingresos      0
# dtype: int64
#
# Ventas:
#  id_venta       0
# producto       0
# precio         2
# cantidad       2
# fecha_venta    0
# categoria      0
# dtype: int64
#
# Marketing:
#  id_campanha     0
# producto        0
# canal           0
# costo           0
# fecha_inicio    0
# fecha_fin       0
# dtype: int64
#
# Duplicados por dataset:
# Clientes: 0
# Ventas: 35
# Marketing: 0
#      Dataset  Filas  Columnas  Duplicados  Valores Nulos Totales
# 0   Clientes    567         5           0                      0
# 1     Ventas   3035         6          35                      4
# 2  Marketing     90         6           0                      0

# %% [markdown]
# # Etapa 2

# %% [markdown]
# ## Limpieza de Datos

# %%
# Eliminación de duplicados
clientes_limpio = clientes.drop_duplicates()
ventas_limpio = ventas.drop_duplicates()
marketing_limpio = marketing.drop_duplicates()

print("Duplicados eliminados:")
print("Clientes:", clientes.shape[0] - clientes_limpio.shape[0])
print("Ventas:", ventas.shape[0] - ventas_limpio.shape[0])
print("Marketing:", marketing.shape[0] - marketing_limpio.shape[0])
# Out:
# Duplicados eliminados:
# Clientes: 0
# Ventas: 35
# Marketing: 0

# %%
# Limpieza de caracteres no deseados
# Por ejemplo, eliminar espacios en blanco, símbolos o caracteres especiales en columnas de texto
for df in [clientes_limpio, ventas_limpio, marketing_limpio]:
    df.columns = df.columns.str.strip()  # limpia espacios en nombres de columnas
    for col in df.select_dtypes(include='object').columns:
        df[col] = df[col].astype(str).str.replace('[^a-zA-Z0-9áéíóúÁÉÍÓÚñÑ\s\.,-]', '', regex=True).str.strip()

print("✔ Limpieza de texto y columnas realizada.")

# Documentación del proceso
documentacion_limpieza = pd.DataFrame({
    'Dataset': ['Clientes', 'Ventas', 'Marketing'],
    'Duplicados Eliminados': [
        clientes.shape[0] - clientes_limpio.shape[0],
        ventas.shape[0] - ventas_limpio.shape[0],
        marketing.shape[0] - marketing_limpio.shape[0]
    ],
    'Filas Finales': [
        clientes_limpio.shape[0],
        ventas_limpio.shape[0],
        marketing_limpio.shape[0]
    ]
})

display(documentacion_limpieza)
# Out:
# ✔ Limpieza de texto y columnas realizada.
# <>:6: SyntaxWarning: invalid escape sequence '\s'
# <>:6: SyntaxWarning: invalid escape sequence '\s'
# /tmp/ipython-input-3584289692.py:6: SyntaxWarning: invalid escape sequence '\s'
#   df[col] = df[col].astype(str).str.replace('[^a-zA-Z0-9áéíóúÁÉÍÓÚñÑ\s\.,-]', '', regex=True).str.strip()
# /tmp/ipython-input-3584289692.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = df[col].astype(str).str.replace('[^a-zA-Z0-9áéíóúÁÉÍÓÚñÑ\s\.,-]', '', regex=True).str.strip()
# /tmp/ipython-input-3584289692.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %% [markdown]
# ## Transformación de Datos

# %%
# Calcular las ventas promedio generales
promedio_ventas = ventas_limpio['total_venta'].mean()

# Filtrar productos con un rendimiento superior al promedio
productos_alto_rendimiento = ventas_limpio[ventas_limpio['total_venta'] > promedio_ventas]

print(f"Promedio general de ventas: ${promedio_ventas:,.2f}")
print(f"Productos de alto rendimiento: {productos_alto_rendimiento.shape[0]} filas")

display(productos_alto_rendimiento.head())
# Out:
# Promedio general de ventas: $489.36
# Productos de alto rendimiento: 1274 filas
#    id_venta           producto  precio  cantidad fecha_venta  \
# 1       811    Lámpara de mesa  105.10       5.0  02/01/2024
# 3      1372           Heladera  114.35       8.0  02/01/2024
# 7      2959          Proyector   88.17       9.0  02/01/2024
# 8       318  Rincón de plantas   79.86      11.0  03/01/2024
# 9       419         Candelabro   66.11       8.0  03/01/2024
#
#            categoria  total_venta
# 1         Decoración       525.50
# 3  Electrodomésticos       914.80
# 7        Electrónica       793.53
# 8         Decoración       878.46
# 9         Decoración       528.88

# %%
# Crear ventas_limpio gestionando valores faltantes y duplicados
ventas_limpio = ventas.dropna(subset=['precio', 'cantidad']).drop_duplicates().copy()

# Convierte 'precio' en numérico eliminando '$' y convirtiendo a flotante
ventas_limpio['precio'] = ventas_limpio['precio'].astype(str).str.replace('$', '', regex=False).astype(float)

# Crear una métrica de rendimiento (por ejemplo, ventas totales por producto)
ventas_limpio['total_venta'] = ventas_limpio['precio'] * ventas_limpio['cantidad']

print("Dimensiones de ventas_limpio después de la limpieza y transformación:", ventas_limpio.shape)
display(ventas_limpio.head())
# Out:
# Dimensiones de ventas_limpio después de la limpieza y transformación: (2998, 7)
#    id_venta           producto  precio  cantidad fecha_venta  \
# 0       792  Cuadro decorativo   69.94       5.0  02/01/2024
# 1       811    Lámpara de mesa  105.10       5.0  02/01/2024
# 2      1156           Secadora   97.96       3.0  02/01/2024
# 3      1372           Heladera  114.35       8.0  02/01/2024
# 4      1546           Secadora  106.21       4.0  02/01/2024
#
#            categoria  total_venta
# 0         Decoración       349.70
# 1         Decoración       525.50
# 2  Electrodomésticos       293.88
# 3  Electrodomésticos       914.80
# 4  Electrodomésticos       424.84

# %% [markdown]
# ## Agregación de Datos

# %%
# Agregación por categoría
ventas_por_categoria = ventas_limpio.groupby('categoria').agg({
    'total_venta': ['sum', 'mean', 'count']
}).reset_index()

# Renombrar columnas para mayor claridad
ventas_por_categoria.columns = ['Categoria', 'Ingreso_Total', 'Promedio_Venta', 'Cantidad_Transacciones']

# Ordenar por mayor ingreso
ventas_por_categoria = ventas_por_categoria.sort_values(by='Ingreso_Total', ascending=False)

display(ventas_por_categoria)

print("✔ Resumen de ventas por categoría generado.")
# Out:
#            Categoria  Ingreso_Total  Promedio_Venta  Cantidad_Transacciones
# 1  Electrodomésticos      505299.63       505.29963                    1000
# 2        Electrónica      482577.80       483.54489                     998
# 0         Decoración      479216.09       479.21609                    1000
# ✔ Resumen de ventas por categoría generado.

# %% [markdown]
# ## Integración de Datos

# %%
# Unir los datasets (por ejemplo, por producto)
datos_integrados = pd.merge(ventas_limpio, marketing_limpio, on='producto', how='left')

# Visualizar el resultado
print("Dimensiones del dataset integrado:", datos_integrados.shape)
display(datos_integrados.head())

# Análisis básico post-integración
print("Columnas combinadas:", datos_integrados.columns.tolist())
print("Valores nulos después de la integración:")
print(datos_integrados.isnull().sum())
# Out:
# Dimensiones del dataset integrado: (8994, 12)
#    id_venta           producto  precio  cantidad fecha_venta   categoria  \
# 0       792  Cuadro decorativo   69.94       5.0  02/01/2024  Decoración
# 1       792  Cuadro decorativo   69.94       5.0  02/01/2024  Decoración
# 2       792  Cuadro decorativo   69.94       5.0  02/01/2024  Decoración
# 3       811    Lámpara de mesa  105.10       5.0  02/01/2024  Decoración
# 4       811    Lámpara de mesa  105.10       5.0  02/01/2024  Decoración
#
#    total_venta  id_campanha  canal  costo fecha_inicio fecha_fin
# 0        349.7            1   RRSS   5.27     27042024  04062024
# 1        349.7           31  Email   5.28     15082024  12092024
# 2        349.7           61     TV   5.30     05112024  23122024
# 3        525.5           32  Email   5.54     28032024  20042024
# 4        525.5            2   RRSS   5.88     30052024  29062024
# ...
